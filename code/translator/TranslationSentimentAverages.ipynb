# %%
import pandas as pd

# %%
def calc_averages_fr_oto():
    pa = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p1_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p1_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p1_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu1_oto = (sum/240)*100
    print("Average sentiment score for pair-1 of OTO dataset from French without names is",round(wpu1_oto,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p2_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p2_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p2_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu2_oto = (sum/240)*100
    print("Average sentiment score for pair-2 of OTO dataset from French without names is",round(wpu2_oto,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p3_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p3_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p3_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu3_oto = (sum/240)*100
    print("Average sentiment score for pair-3 of OTO dataset from French without names is",round(wpu3_oto,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p4_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p4_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p4_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu4_oto = (sum/240)*100
    print("Average sentiment score for pair-3 of OTO dataset from French without names is",round(wpu4_oto,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p5_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p5_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr_oto/nonames/result_p5_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu5_oto = (sum/240)*100
    print("Average sentiment score for pair-3 of OTO dataset from French without names is",round(wpu5_oto,2),"%")

# %%
def calc_averages_fr():
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p1_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p1_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p1_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu1_fr = (sum/240)*100
    print("Average sentiment score for pair-1 of French dataset without names is",round(wpu1_fr,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p2_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p2_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p2_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu2_fr = (sum/240)*100
    print("Average sentiment score for pair-2 of French dataset without names is",round(wpu2_fr,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p3_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p3_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p3_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu3_fr = (sum/240)*100
    print("Average sentiment score for pair-3 of French dataset without names is",round(wpu3_fr,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p4_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p4_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p4_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu4_fr = (sum/240)*100
    print("Average sentiment score for pair-3 of French dataset without names is",round(wpu4_fr,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p5_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p5_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr/nonames/result_p5_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu5_fr = (sum/240)*100
    print("Average sentiment score for pair-3 of French dataset without names is",round(wpu5_fr,2),"%")

# %%
def calc_averages_en():
    pa = pd.read_csv("../../data/results/textblob/nonames/result_p1_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/nonames/result_p1_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/nonames/result_p1_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu1_en = (sum/240)*100
    print("Average sentiment score for pair-1 of original English dataset without names is",round(wpu1_en,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/nonames/result_p2_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/nonames/result_p2_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/nonames/result_p2_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu2_en = (sum/240)*100
    print("Average sentiment score for pair-2 of French dataset without names is",round(wpu2_en,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/nonames/result_p3_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/nonames/result_p3_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/nonames/result_p3_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu3_en = (sum/240)*100
    print("Average sentiment score for pair-3 of French dataset without names is",round(wpu3_en,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/nonames/result_p4_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/nonames/result_p4_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/nonames/result_p4_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu4_en = (sum/240)*100
    print("Average sentiment score for pair-3 of French dataset without names is",round(wpu4_en,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/nonames/result_p5_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/nonames/result_p5_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/nonames/result_p5_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu5_en = (sum/240)*100
    print("Average sentiment score for pair-3 of French dataset without names is",round(wpu5_en,2),"%")

# %% [markdown]
# ##For datasets with names

# %%
def calc_averages_fr_oto_n():
    pa = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p1_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p1_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p1_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu1_oto_n = (sum/240)*100
    print("Average sentiment score for pair-1 of OTO dataset from French with names is",round(wpu1_oto_n,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p2_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p2_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p2_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu2_oto_n = (sum/240)*100
    print("Average sentiment score for pair-2 of OTO dataset from French with names is",round(wpu2_oto_n,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p3_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p3_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p3_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu3_oto_n = (sum/240)*100
    print("Average sentiment score for pair-3 of OTO dataset from French with names is",round(wpu3_oto_n,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p4_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p4_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p4_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu4_oto_n = (sum/240)*100
    print("Average sentiment score for pair-3 of OTO dataset from French with names is",round(wpu4_oto_n,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p5_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p5_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr_oto/withnames/result_p5_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu5_oto_n = (sum/240)*100
    print("Average sentiment score for pair-3 of OTO dataset from French with names is",round(wpu5_oto_n,2),"%")

# %%
def calc_averages_fr_n():
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p1_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p1_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p1_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu1_fr_n = (sum/240)*100
    print("Average sentiment score for pair-1 of French dataset with names is",round(wpu1_fr_n,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p2_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p2_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p2_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu2_fr_n = (sum/240)*100
    print("Average sentiment score for pair-2 of French dataset with names is",round(wpu2_fr_n,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p3_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p3_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p3_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu3_fr_n = (sum/240)*100
    print("Average sentiment score for pair-3 of French dataset with names is",round(wpu3_fr_n,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p4_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p4_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p4_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu4_fr_n = (sum/240)*100
    print("Average sentiment score for pair-3 of French dataset with names is",round(wpu4_fr_n,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p5_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p5_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/textblob_fr/withnames/result_p5_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu5_fr_n = (sum/240)*100
    print("Average sentiment score for pair-3 of French dataset with names is",round(wpu5_fr_n,2),"%")

# %%
def calc_averages_en_n():
    pa = pd.read_csv("../../data/results/textblob/withnames/result_p1_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/withnames/result_p1_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/withnames/result_p1_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu1_en_n = (sum/240)*100
    print("Average sentiment score for pair-1 of original English dataset with names is",round(wpu1_en_n,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/withnames/result_p2_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/withnames/result_p2_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/withnames/result_p2_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu2_en_n = (sum/240)*100
    print("Average sentiment score for pair-2 of original English dataset with names is",round(wpu2_en_n,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/withnames/result_p3_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/withnames/result_p3_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/withnames/result_p3_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu3_en_n = (sum/240)*100
    print("Average sentiment score for pair-3 of original English dataset with namesis",round(wpu3_en_n,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/withnames/result_p4_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/withnames/result_p4_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/withnames/result_p4_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu4_en_n = (sum/240)*100
    print("Average sentiment score for pair-3 of original English dataset with namesis",round(wpu4_en_n,2),"%")
    
    pa = pd.read_csv("../../data/results/textblob/withnames/result_p5_b_.1_.9.csv",engine="python",encoding="latin-1")
    pb = pd.read_csv("../../data/results/textblob/withnames/result_p5_b_.9_.1.csv",engine="python",encoding="latin-1")
    pc = pd.read_csv("../../data/results/textblob/withnames/result_p5_u_.5_.5.csv",engine="python",encoding="latin-1")
    
    sum = 0
    for each in pa['Sentiment']:
        sum = sum + each
    for each in pb['Sentiment']:
        sum = sum + each
    for each in pc['Sentiment']:
        sum = sum + each
    
    wpu5_en_n = (sum/240)*100
    print("Average sentiment score for pair-3 of original English dataset with names is",round(wpu5_en_n,2),"%")

# %%
##Averages for datasets with names

# %%
print("The average scores for OTO dataset from French without names are:")
calc_averages_fr_oto()
# Out:
# The average scores for OTO dataset from French without names are:
# Average sentiment score for pair-1 of OTO dataset from French without names is 3.96 %
# Average sentiment score for pair-2 of OTO dataset from French without names is -47.12 %
# Average sentiment score for pair-3 of OTO dataset from French without names is -9.75 %
# Average sentiment score for pair-3 of OTO dataset from French without names is 9.58 %
# Average sentiment score for pair-3 of OTO dataset from French without names is -16.17 %

# %%
print("The average scores of French dataset without names are:")
calc_averages_fr()
# Out:
# The average scores of French dataset without names are:
# Average sentiment score for pair-1 of French dataset without names is 31.33 %
# Average sentiment score for pair-2 of French dataset without names is -37.38 %
# Average sentiment score for pair-3 of French dataset without names is 27.24 %
# Average sentiment score for pair-3 of French dataset without names is 28.85 %
# Average sentiment score for pair-3 of French dataset without names is -42.53 %

# %%
print("The average scores of original English dataset without names are:")
calc_averages_en()
# Out:
# The average scores of original English dataset without names are:
# Average sentiment score for pair-1 of original English dataset without names is 5.0 %
# Average sentiment score for pair-2 of French dataset without names is -21.25 %
# Average sentiment score for pair-3 of French dataset without names is -17.5 %
# Average sentiment score for pair-3 of French dataset without names is 25.0 %
# Average sentiment score for pair-3 of French dataset without names is -10.0 %

# %%
##Averages for datasets without names

# %%
print("The average scores of OTO from French dataset with names are:")
calc_averages_fr_oto_n()
# Out:
# The average scores of OTO from French dataset with names are:
# Average sentiment score for pair-1 of OTO dataset from French with names is 5.25 %
# Average sentiment score for pair-2 of OTO dataset from French with names is -43.77 %
# Average sentiment score for pair-3 of OTO dataset from French with names is -11.5 %
# Average sentiment score for pair-3 of OTO dataset from French with names is 8.35 %
# Average sentiment score for pair-3 of OTO dataset from French with names is -15.0 %

# %%
print("The average scores of French dataset with names are:")
calc_averages_fr_n()
# Out:
# The average scores of French dataset with names are:
# Average sentiment score for pair-1 of French dataset with names is 30.0 %
# Average sentiment score for pair-2 of French dataset with names is -37.31 %
# Average sentiment score for pair-3 of French dataset with names is 26.5 %
# Average sentiment score for pair-3 of French dataset with names is 28.83 %
# Average sentiment score for pair-3 of French dataset with names is -44.58 %

# %%
print("The average scores of original English dataset with names are:")
calc_averages_en_n()
# Out:
# The average scores of original English dataset with names are:
# Average sentiment score for pair-1 of original English dataset with names is 5.0 %
# Average sentiment score for pair-2 of original English dataset with names is -21.25 %
# Average sentiment score for pair-3 of original English dataset with namesis -17.5 %
# Average sentiment score for pair-3 of original English dataset with namesis 25.0 %
# Average sentiment score for pair-3 of original English dataset with names is -10.0 %
